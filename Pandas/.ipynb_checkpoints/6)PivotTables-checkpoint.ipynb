# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# ## Pivot table

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)

df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    117     28   John  January      Q1
# 1  2023-01-02       B   West    262     40   Mary  January      Q1
# 2  2023-01-03       C  North    212     26    Bob  January      Q1
# 3  2023-01-04       D  South    246     71  Alice  January      Q1
# 4  2023-01-05       A   East    785     17   John  January      Q1
# 5  2023-01-06       B   West    905     74   Mary  January      Q1
# 6  2023-01-07       C  North    252     88    Bob  January      Q1
# 7  2023-01-08       D  South    785     65  Alice  January      Q1
# 8  2023-01-09       A   East    122     82   John  January      Q1
# 9  2023-01-10       B   West    530     16   Mary  January      Q1
# 10 2023-01-11       C  North    850     80    Bob  January      Q1
# 11 2023-01-12       D  South    882     89  Alice  January      Q1
# 12 2023-01-13       A   East    472     50   John  January      Q1
# 13 2023-01-14       B   West    334     50   Mary  January      Q1
# 14 2023-01-15       C  North    737     28    Bob  January      Q1
# 15 2023-01-16       D  South    126     68  Alice  January      Q1
# 16 2023-01-17       A   East    796     15   John  January      Q1
# 17 2023-01-18       B   West    687     55   Mary  January      Q1
# 18 2023-01-19       C  North    251     62    Bob  January      Q1
# 19 2023-01-20       D  South    279     66  Alice  January      Q1

# %%
pd.pivot_table(df, values = 'Sales', index = 'Region', columns = 'Product')
# Out:
# Product      A      B      C      D
# Region
# East     458.4    NaN    NaN    NaN
# North      NaN    NaN  460.4    NaN
# South      NaN    NaN    NaN  463.6
# West       NaN  543.6    NaN    NaN

# %% [markdown]
# Here, the values are aggregated values i.e MEAN, we can provide or get other aggregated values too.

# %%
pd.pivot_table(df, values = 'Sales', index = 'Region', columns = 'Product', aggfunc = 'median')
# Out:
# Product      A      B      C      D
# Region
# East     472.0    NaN    NaN    NaN
# North      NaN    NaN  252.0    NaN
# South      NaN    NaN    NaN  279.0
# West       NaN  530.0    NaN    NaN

# %%
# Pivot table is mostly used to create HITMAPS.

# %%
pivot2  = pd.pivot_table(df, values = ['Sales', 'Units'], index = 'Region', columns = 'Product')
pivot2
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     458.4    NaN    NaN    NaN  38.4   NaN   NaN   NaN
# North      NaN    NaN  460.4    NaN   NaN   NaN  56.8   NaN
# South      NaN    NaN    NaN  463.6   NaN   NaN   NaN  71.8
# West       NaN  543.6    NaN    NaN   NaN  47.0   NaN   NaN

# %%
# The values in the pivot table must be NUMERIC as we need to use AGGREGATE function on them

# %% [markdown]
# ## Cross tabs
#
# There is a small difference in Cross tabs and Pivot table
#
# In pivot tables, we used aggregate function while in Cross tabs we use counting function

# %%
pd.crosstab(df['Region'], df['Product'])
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0
