# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# We use distribution plots to visualize the distribution of quantitative data.
#
# Different types of plots that allows us to visualize the distribution of data sets are:
# - distplot/histplot
# - jointplot
# - pairplot
# - rugplot

# %% [markdown]
# ## histplot

# %%
# there is default datasets in the seaborn and we can use them directly, we can check the datasets in the github of seaborn 
df = sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# the size has numbers and at first glance it seems like it is quantitative but it is qualitative/categorical data

# %%
df['size'].unique()
# Out:
# array([2, 3, 4, 1, 6, 5])

# %% [markdown]
# This is not quantitative, it is qualitative

# %%
sns.displot(df['total_bill'])

# %% [markdown]
# Using histogram we make a curve [bell curve] and bell curve occurs when there is normal distribution
#
# The bars are known as BINS and we can change it, default is 20

# %%
sns.displot(df['total_bill'], bins = 1)

# %%
sns.displot(df['total_bill'], bins = 5)

# %%
sns.displot(df['total_bill'], bins = 100)

# %% [markdown]
# There is Kernel Density Estimation(KDE) in historgram, and it is a curve around the plots, and helps us to identify the skwness of the data. [right skewed, left skewed, normal distributed]

# %%
sns.displot(df['total_bill'], bins = 20, kde = True)

# Instead of displot it is better to use histplot, displot is going to be removed

# %%
plt.subplot(1, 2, 1)
sns.histplot(df['total_bill'], bins = 20, kde = True)
plt.subplot(1, 2, 2)
sns.histplot(df['tip'], bins = 20, kde = True)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %% [markdown]
# ## Jointplot
#
# It is used to compare two datas in the plot

# %%
sns.jointplot(x = 'total_bill', y = 'tip', data = df, kind = 'scatter')

# %%
sns.jointplot(x = 'total_bill', y = 'tip', data = df, kind = 'kde')

# %%
sns.jointplot(x = 'total_bill', y = 'tip', data = df, kind = 'hex')

# %%
sns.jointplot(x = 'total_bill', y = 'tip', data = df, kind = 'hist')

# %%
sns.jointplot(x = 'total_bill', y = 'tip', data = df, kind = 'reg')

# %% [markdown]
# ## pairplot
#
# It is important and used at first for analysis

# %%
sns.pairplot(df)

# %%
sns.pairplot(df, hue = 'sex')

# %%
sns.pairplot(df, hue = 'sex', palette = 'rainbow')

# %%
sns.pairplot(df, hue = 'size', palette = 'rainbow')

# %% [markdown]
# ## rugplot

# %%
sns.rugplot(df['total_bill'])
# Out:
# <Axes: xlabel='total_bill'>

# %%
sns.rugplot(df)
# Out:
# <Axes: >
